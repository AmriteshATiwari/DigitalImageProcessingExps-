# %% [markdown]
# # Simple Histogarm

# %%
import cv2
import numpy as np
from matplotlib import pyplot as plt


img = cv2.imread(r'Cameraman.png')
img1=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
hist = cv2.calcHist([img1],[0],None,[256],[0,256])


plt.plot(hist, color='b')
plt.show()

# %% [markdown]
# # Equilization Histogarm

# %%
import cv2
import numpy as np
img = cv2.imread('Cameraman.png', 0)

equ = cv2.equalizeHist(img)


hist = cv2.calcHist([equ],[0],None,[256],[0,256])
plt.plot(hist, color='b')
plt.show()


res = np.hstack((img, equ))

cv2.imshow('image', res)
plt.imshow(res)
cv2.waitKey(0)
cv2.destroyAllWindows()

# %% [markdown]
# # Matching Histogram

# %%
import matplotlib.pyplot as plt
from skimage import data
from skimage import exposure
from skimage.exposure import match_histograms


reference = data.moon()
image = data.camera()


matched = match_histograms(image, reference,multichannel=True,channel_axis=-1)

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3,figsize=(8, 3),sharex=True,sharey=True)
for aa in (ax1, ax2, ax3):
     aa.set_axis_off()


ax1.imshow(image)
ax1.set_title('Source image')
ax2.imshow(reference)
ax2.set_title('Reference image')
ax3.imshow(matched)
ax3.set_title('Matched image')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3788\2441670593.py:11: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched = match_histograms(image, reference,multichannel=True,channel_axis=-1)

# %%
import cv2
import matplotlib.pyplot as plt
from skimage import data
from skimage import exposure
from skimage.exposure import match_histograms

img = cv2.imread(r'Cameraman.png')
img2 = cv2.imread(r'lenna.png')
reference = img
image =img2


matched = match_histograms(image, reference,multichannel=True,)

fig, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3,figsize=(8, 3),sharex=True,sharey=True)
for aa in (ax1, ax2, ax3):
     aa.set_axis_off()


ax1.imshow(image)
ax1.set_title('Source image')
ax2.imshow(reference)
ax2.set_title('Reference image')
ax3.imshow(matched)
ax3.set_title('Matched image')

plt.tight_layout()
cv2.waitKey(0)
plt.show()
# Out:
# C:\Users\Dell\AppData\Local\Temp\ipykernel_3788\3880870588.py:13: FutureWarning: `multichannel` is a deprecated argument name for `match_histograms`. It will be removed in version 1.0. Please use `channel_axis` instead.
#   matched = match_histograms(image, reference,multichannel=True,)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_3788\3880870588.py in <module>
#      11
#      12
# ---> 13 matched = match_histograms(image, reference,multichannel=True,)
#      14
#      15 fig, (ax1, ax2, ax3) = plt.subplots(nrows=1,ncols=3,figsize=(8, 3),sharex=True,sharey=True)
#
# D:\Anaconda\lib\site-packages\skimage\_shared\utils.py in fixed_func(*args, **kwargs)
#     392
#     393             if channel_axis is None:
# --> 394                 return func(*args, **kwargs)
#     395
# ...
